# %%
# load data from csv
# path for input and target data tables

diagnosis_path = '../../data/test_phase_2/diagnosis_hadm.csv'
discharge_path ='../../data/test_phase_2/discharge.csv'
edstays_path = '../../data/test_phase_2/edstays.csv'
radiology_path = '../../data/test_phase_2/radiology.csv'
triage_path = '../../data/test_phase_2/triage.csv'
target_path = '../../data/test_phase_2/discharge_target.csv'
discharge_sections_path = '../../data/test_phase_2/discharge_sections.csv'
radiology_sections_path = '../../data/test_phase_2/radiology_sections.csv'

import pandas as pd
import re
import os

# read data
diagnosis_df = pd.read_csv(diagnosis_path, keep_default_na=False)
discharge_df = pd.read_csv(discharge_path, keep_default_na=False)
edstays_df = pd.read_csv(edstays_path, keep_default_na=False)
radiology_df = pd.read_csv(radiology_path, keep_default_na=False)
triage_df = pd.read_csv(triage_path, keep_default_na=False)
target_df = pd.read_csv(target_path, keep_default_na=False)

discharge_sections_df = pd.read_csv(discharge_sections_path, keep_default_na=False)
radiology_sections_df = pd.read_csv(radiology_sections_path, keep_default_na=False)
# Out:
# /home/tr.caron/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/tr.caron/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
# !pwd
# Out:
# /work/AI-EHR/discharge_me/Notebooks/troy_notebooks

# %%
# !pip install --upgrade numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (1.21.5)
# Collecting numpy
#   Using cached numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# xformers 0.0.27.post2 requires torch==2.4.0, but you have torch 2.4.1 which is incompatible.
# vllm 0.6.0 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# vllm 0.6.0 requires torch==2.4.0, but you have torch 2.4.1 which is incompatible.
# torchvision 0.19.0 requires torch==2.4.0, but you have torch 2.4.1 which is incompatible.
# outlines 0.0.46 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2

# %%
pip install --upgrade numba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numba in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (0.55.1)
# Collecting numba
#   Downloading numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 4.3 MB/s eta 0:00:01
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      |████████████████████████████████| 43.9 MB 78.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2.1,>=1.22 in /home/tr.caron/.local/lib/python3.9/site-packages (from numba) (2.0.2)
# Installing collected packages: llvmlite, numba
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# outlines 0.0.46 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# Successfully installed llvmlite-0.43.0 numba-0.60.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade jsonschema
# !pip install -U ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jsonschema in /home/tr.caron/.local/lib/python3.9/site-packages (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema) (0.20.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema) (0.35.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/tr.caron/.local/lib/python3.9/site-packages (7.7.1)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Collecting jupyterlab-widgets~=3.0.12
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Requirement already satisfied: traitlets>=4.3.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Collecting widgetsnbextension~=4.0.12
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: ipython>=6.1.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets) (8.2.0)
# Collecting comm>=0.1.3
#   Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (61.2.0)
# Requirement already satisfied: pickleshare in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: stack-data in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: backcall in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: six in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.9
#     Uninstalling widgetsnbextension-3.6.9:
#       Successfully uninstalled widgetsnbextension-3.6.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed comm-0.2.2 ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
# !huggingface-cli login

# %%
# !pip install vllm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vllm in /home/tr.caron/.local/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: pyzmq in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (22.3.0)
# Requirement already satisfied: pydantic>=2.8 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.9.1)
# Requirement already satisfied: importlib-metadata in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (4.11.3)
# Requirement already satisfied: torchvision==0.19 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: requests in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: pyyaml in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (6.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.7.0)
# Requirement already satisfied: py-cpuinfo in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: sentencepiece in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.2.0)
# Requirement already satisfied: aiohttp in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (3.8.1)
# Requirement already satisfied: msgspec in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.18.6)
# Requirement already satisfied: transformers>=4.43.2 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (4.44.2)
# Requirement already satisfied: tqdm in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (4.66.5)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.19.1)
# Collecting torch==2.4.0
#   Using cached torch-2.4.0-cp39-cp39-manylinux1_x86_64.whl (797.2 MB)
# Requirement already satisfied: vllm-flash-attn==2.6.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.6.1)
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      |████████████████████████████████| 18.2 MB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: filelock>=3.10.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (3.16.0)
# Requirement already satisfied: mistral-common>=1.3.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (1.4.0)
# Requirement already satisfied: lm-format-enforcer==0.10.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.10.6)
# Requirement already satisfied: protobuf in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (3.19.1)
# Requirement already satisfied: openai>=1.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (1.44.1)
# Requirement already satisfied: nvidia-ml-py in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (12.560.30)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (7.0.0)
# Requirement already satisfied: ray>=2.9 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.35.0)
# Requirement already satisfied: uvicorn[standard] in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.30.6)
# Requirement already satisfied: pillow in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (10.4.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.20.0)
# Requirement already satisfied: outlines<0.1,>=0.0.43 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.0.46)
# Requirement already satisfied: fastapi in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.114.1)
# Requirement already satisfied: psutil in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (5.8.0)
# Requirement already satisfied: xformers==0.0.27.post2 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.0.27.post2)
# Requirement already satisfied: typing-extensions>=4.10 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (4.12.2)
# Requirement already satisfied: partial-json-parser in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.2.1.1.post4)
# Requirement already satisfied: gguf==0.9.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.9.1)
# Requirement already satisfied: interegular>=0.3.2 in /home/tr.caron/.local/lib/python3.9/site-packages (from lm-format-enforcer==0.10.6->vllm) (0.3.3)
# Requirement already satisfied: packaging in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from lm-format-enforcer==0.10.6->vllm) (21.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (2.20.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (10.3.2.106)
# Requirement already satisfied: fsspec in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (2024.6.1)
# Requirement already satisfied: sympy in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch==2.4.0->vllm) (1.10.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (9.1.0.70)
# Requirement already satisfied: jinja2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch==2.4.0->vllm) (2.11.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (3.0.0)
# Requirement already satisfied: networkx in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch==2.4.0->vllm) (2.7.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch==2.4.0->vllm) (11.4.5.107)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/tr.caron/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->vllm) (12.6.68)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from mistral-common>=1.3.4->vllm) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (0.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (0.35.1)
# Requirement already satisfied: sniffio in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from openai>=1.0->vllm) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from openai>=1.0->vllm) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (0.5.0)
# Requirement already satisfied: idna>=2.8 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.0->vllm) (3.3)
# Requirement already satisfied: certifi in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai>=1.0->vllm) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in /home/tr.caron/.local/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai>=1.0->vllm) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->vllm) (0.14.0)
# Requirement already satisfied: diskcache in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (5.6.3)
# Requirement already satisfied: pycountry in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (24.6.1)
# Requirement already satisfied: lark in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.2.2)
# Requirement already satisfied: nest-asyncio in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.5.5)
# Requirement already satisfied: cloudpickle in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (2.0.0)
# Requirement already satisfied: datasets in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (3.0.0)
# Requirement already satisfied: numba in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (0.60.0)
# Requirement already satisfied: pyairports in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (2.1.1)
# Requirement already satisfied: starlette<1.0.0,>=0.30.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from prometheus-fastapi-instrumentator>=7.0.0->vllm) (0.38.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from pydantic>=2.8->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/tr.caron/.local/lib/python3.9/site-packages (from pydantic>=2.8->vllm) (2.23.3)
# Requirement already satisfied: frozenlist in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.2.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.0.2)
# Requirement already satisfied: click>=7.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (8.0.4)
# Requirement already satisfied: aiosignal in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from requests->vllm) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from requests->vllm) (2.0.4)
# Requirement already satisfied: regex>=2022.1.18 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from tiktoken>=0.6.0->vllm) (2022.3.15)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from tokenizers>=0.19.1->vllm) (0.24.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from packaging->lm-format-enforcer==0.10.6->vllm) (3.0.4)
# Requirement already satisfied: safetensors>=0.4.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers>=4.43.2->vllm) (0.4.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (1.6.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (4.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (5.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.3.8)
# Requirement already satisfied: xxhash in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (3.5.0)
# Requirement already satisfied: pandas in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (1.4.2)
# Requirement already satisfied: multiprocess in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.70.16)
# Requirement already satisfied: zipp>=0.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from importlib-metadata->vllm) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jinja2->torch==2.4.0->vllm) (2.0.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/tr.caron/.local/lib/python3.9/site-packages (from numba->outlines<0.1,>=0.0.43->vllm) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2021.3)
# Requirement already satisfied: six>=1.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets->outlines<0.1,>=0.0.43->vllm) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from sympy->torch==2.4.0->vllm) (1.2.1)
# Requirement already satisfied: websockets>=10.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (13.0.1)
# Requirement already satisfied: httptools>=0.5.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.24.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Installing collected packages: numpy, torch
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
# ERROR: Could not install packages due to an OSError: [Errno 39] Directory not empty: 'lib'

# %%
pip install torch --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/tr.caron/.local/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: fsspec in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: jinja2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: networkx in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (2.7.1)
# Requirement already satisfied: sympy in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (1.10.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: filelock in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/tr.caron/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from sympy->torch) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import login
from config import HF_TOKEN
login(token=HF_TOKEN)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/tr.caron/.cache/huggingface/token
# Login successful

# %%
# !pip install ipywidgets==7.7.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets==7.7.1 in /home/tr.caron/.local/lib/python3.9/site-packages (7.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from ipywidgets==7.7.1) (3.6.9)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets==7.7.1) (6.9.1)
# Requirement already satisfied: ipython>=4.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets==7.7.1) (8.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets==7.7.1) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipywidgets==7.7.1) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.1.12)
# Requirement already satisfied: nest-asyncio in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (1.5.5)
# Requirement already satisfied: pickleshare in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (2.11.2)
# Requirement already satisfied: decorator in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (4.8.0)
# Requirement already satisfied: backcall in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (61.2.0)
# Requirement already satisfied: stack-data in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.7.1) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.7.1) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.7.1) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1) (0.7.0)
# Requirement already satisfied: wcwidth in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.7.1) (0.2.5)
# Requirement already satisfied: six>=1.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.7.1) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.8.0)
# Requirement already satisfied: argon2-cffi in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (21.3.0)
# Requirement already satisfied: jinja2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.11.3)
# Requirement already satisfied: nbformat in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (5.3.0)
# Requirement already satisfied: prometheus-client in /home/tr.caron/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.20.0)
# Requirement already satisfied: nbconvert in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.13.1)
# Requirement already satisfied: argon2-cffi-bindings in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.15.0)
# Requirement already satisfied: pycparser in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.4)
# Requirement already satisfied: bleach in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.5.13)
# Requirement already satisfied: testpath in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.5.0)
# Requirement already satisfied: defusedxml in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.5.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.23.0)
# Requirement already satisfied: fastjsonschema in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.15.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.20.0)
# Requirement already satisfied: soupsieve>1.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.3.1)
# Requirement already satisfied: webencodings in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.5.1)
# Requirement already satisfied: packaging in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.0.4)
# Requirement already satisfied: pure-eval in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1) (0.2.2)
# Requirement already satisfied: asttokens in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1) (2.0.5)
# Requirement already satisfied: executing in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1) (0.8.3)

# %%
pip install torch transformers vllm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/tr.caron/.local/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: transformers in /home/tr.caron/.local/lib/python3.9/site-packages (4.44.2)
# Requirement already satisfied: vllm in /home/tr.caron/.local/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: jinja2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: filelock in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (3.16.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: triton==3.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (2.7.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: fsspec in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/tr.caron/.local/lib/python3.9/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: sympy in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from torch) (1.10.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/tr.caron/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.68)
# Requirement already satisfied: safetensors>=0.4.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: regex!=2019.12.17 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: numpy>=1.17 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: requests in /home/tr.caron/.local/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: psutil in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (5.8.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.7.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.20.0)
# Requirement already satisfied: nvidia-ml-py in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (12.560.30)
# Requirement already satisfied: partial-json-parser in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.2.1.1.post4)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (7.0.0)
# Requirement already satisfied: torchvision==0.19 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: vllm-flash-attn==2.6.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.6.1)
# Collecting torch
#   Using cached torch-2.4.0-cp39-cp39-manylinux1_x86_64.whl (797.2 MB)
# Requirement already satisfied: fastapi in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.114.1)
# Requirement already satisfied: pyzmq in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (22.3.0)
# Requirement already satisfied: importlib-metadata in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (4.11.3)
# Requirement already satisfied: xformers==0.0.27.post2 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.0.27.post2)
# Requirement already satisfied: uvicorn[standard] in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.30.6)
# Requirement already satisfied: pydantic>=2.8 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.9.1)
# Requirement already satisfied: protobuf in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (3.19.1)
# Requirement already satisfied: msgspec in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.18.6)
# Requirement already satisfied: mistral-common>=1.3.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (1.4.0)
# Requirement already satisfied: gguf==0.9.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.9.1)
# Requirement already satisfied: pillow in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (10.4.0)
# Requirement already satisfied: lm-format-enforcer==0.10.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.10.6)
# Requirement already satisfied: ray>=2.9 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (2.35.0)
# Requirement already satisfied: outlines<0.1,>=0.0.43 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.0.46)
# Requirement already satisfied: sentencepiece in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (0.2.0)
# Requirement already satisfied: aiohttp in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from vllm) (3.8.1)
# Requirement already satisfied: openai>=1.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (1.44.1)
# Requirement already satisfied: py-cpuinfo in /home/tr.caron/.local/lib/python3.9/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: interegular>=0.3.2 in /home/tr.caron/.local/lib/python3.9/site-packages (from lm-format-enforcer==0.10.6->vllm) (0.3.3)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from mistral-common>=1.3.4->vllm) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (0.20.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.3.4->vllm) (0.35.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (1.9.0)
# Requirement already satisfied: sniffio in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from openai>=1.0->vllm) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from openai>=1.0->vllm) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from openai>=1.0->vllm) (3.5.0)
# Requirement already satisfied: idna>=2.8 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.0->vllm) (3.3)
# Requirement already satisfied: httpcore==1.* in /home/tr.caron/.local/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai>=1.0->vllm) (1.0.5)
# Requirement already satisfied: certifi in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai>=1.0->vllm) (2021.10.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->vllm) (0.14.0)
# Requirement already satisfied: numba in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (0.60.0)
# Requirement already satisfied: pycountry in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (24.6.1)
# Requirement already satisfied: datasets in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (3.0.0)
# Requirement already satisfied: nest-asyncio in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.5.5)
# Requirement already satisfied: pyairports in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (2.1.1)
# Requirement already satisfied: cloudpickle in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (2.0.0)
# Requirement already satisfied: diskcache in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (5.6.3)
# Requirement already satisfied: lark in /home/tr.caron/.local/lib/python3.9/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: starlette<1.0.0,>=0.30.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from prometheus-fastapi-instrumentator>=7.0.0->vllm) (0.38.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from pydantic>=2.8->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/tr.caron/.local/lib/python3.9/site-packages (from pydantic>=2.8->vllm) (2.23.3)
# Requirement already satisfied: frozenlist in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.2.0)
# Requirement already satisfied: aiosignal in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.2.0)
# Requirement already satisfied: click>=7.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (8.0.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from ray>=2.9->vllm) (1.0.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (1.6.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from aiohttp->vllm) (4.0.1)
# Requirement already satisfied: pandas in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (1.4.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (17.0.0)
# Requirement already satisfied: xxhash in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (3.5.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.3.8)
# Requirement already satisfied: multiprocess in /home/tr.caron/.local/lib/python3.9/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.70.16)
# Requirement already satisfied: zipp>=0.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from importlib-metadata->vllm) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/tr.caron/.local/lib/python3.9/site-packages (from numba->outlines<0.1,>=0.0.43->vllm) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2021.3)
# Requirement already satisfied: six>=1.5 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets->outlines<0.1,>=0.0.43->vllm) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages (from sympy->torch) (1.2.1)
# Requirement already satisfied: httptools>=0.5.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.24.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (0.20.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: websockets>=10.4 in /home/tr.caron/.local/lib/python3.9/site-packages (from uvicorn[standard]->vllm) (13.0.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
# Successfully installed torch-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show torch
# Out:
# Name: torch
# Version: 2.4.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /home/tr.caron/.local/lib/python3.9/site-packages
# Requires: nvidia-cuda-nvrtc-cu12, nvidia-cudnn-cu12, nvidia-cublas-cu12, nvidia-curand-cu12, sympy, jinja2, typing-extensions, nvidia-cuda-runtime-cu12, nvidia-nvtx-cu12, nvidia-cufft-cu12, networkx, nvidia-cusparse-cu12, nvidia-cusolver-cu12, filelock, nvidia-cuda-cupti-cu12, nvidia-nccl-cu12, triton, fsspec
# Required-by: xformers, vllm, vllm-flash-attn, torchvision
# Note: you may need to restart the kernel to use updated packages.

# %%
from vllm import LLM, SamplingParams
from transformers import AutoTokenizer

# Initialize the LLM object with the specified model
model = LLM(model="meta-llama/Meta-Llama-3-8B-Instruct")
# model = LLM(model="meta-llama/Meta-Llama-3-8B")
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Meta-Llama-3-8B')
# Imports
import torch
# generate_prompt function
def generate_prompt(instruction, input=None):
    if input:
        return f"""Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request. 
 
### Instruction:
{instruction}

### Input:
{input}

### Response:
"""
    else:
        return f"""Below is an instruction that describes a task. Write a response that appropriately completes the request.  # noqa: E501

### Instruction:
{instruction}

### Response:
"""
# Out:
# WARNING 09-12 16:11:30 _custom_ops.py:18] Failed to import from vllm._C with ImportError('libcuda.so.1: cannot open shared object file: No such file or directory')

# %%
SamplingParams?
# Out:
# Init signature:
# SamplingParams(
#     n: int = 1,
#     best_of: Optional[int] = None,
#     presence_penalty: float = 0.0,
#     frequency_penalty: float = 0.0,
#     repetition_penalty: float = 1.0,
#     temperature: float = 1.0,
#     top_p: float = 1.0,
#     top_k: int = -1,
#     min_p: float = 0.0,
#     seed: Optional[int] = None,
#     use_beam_search: bool = False,
#     length_penalty: float = 1.0,
#     early_stopping: Union[bool, str] = False,
#     stop: Union[str, List[str], NoneType] = None,
#     stop_token_ids: Optional[List[int]] = None,
#     ignore_eos: bool = False,
#     max_tokens: Optional[int] = 16,
#     min_tokens: int = 0,
#     logprobs: Optional[int] = None,
#     prompt_logprobs: Optional[int] = None,
#     detokenize: bool = True,
#     skip_special_tokens: bool = True,
#     spaces_between_special_tokens: bool = True,
#     logits_processors: Optional[Any] = None,
#     include_stop_str_in_output: bool = False,
#     truncate_prompt_tokens: Optional[Annotated[int, msgspec.Meta(ge=1)]] = None,
#     output_text_buffer_length: int = 0,
#     _all_stop_token_ids: Set[int] = <factory>,
# )
# Docstring:
# Sampling parameters for text generation.
#
# Overall, we follow the sampling parameters from the OpenAI text completion
# API (https://platform.openai.com/docs/api-reference/completions/create).
# In addition, we support beam search, which is not supported by OpenAI.
#
# Args:
#     n: Number of output sequences to return for the given prompt.
#     best_of: Number of output sequences that are generated from the prompt.
#         From these `best_of` sequences, the top `n` sequences are returned.
#         `best_of` must be greater than or equal to `n`. This is treated as
#         the beam width when `use_beam_search` is True. By default, `best_of`
#         is set to `n`.
#     presence_penalty: Float that penalizes new tokens based on whether they
#         appear in the generated text so far. Values > 0 encourage the model
#         to use new tokens, while values < 0 encourage the model to repeat
#         tokens.
#     frequency_penalty: Float that penalizes new tokens based on their
#         frequency in the generated text so far. Values > 0 encourage the
#         model to use new tokens, while values < 0 encourage the model to
#         repeat tokens.
#     repetition_penalty: Float that penalizes new tokens based on whether
#         they appear in the prompt and the generated text so far. Values > 1
#         encourage the model to use new tokens, while values < 1 encourage
#         the model to repeat tokens.
#     temperature: Float that controls the randomness of the sampling. Lower
#         values make the model more deterministic, while higher values make
#         the model more random. Zero means greedy sampling.
#     top_p: Float that controls the cumulative probability of the top tokens
#         to consider. Must be in (0, 1]. Set to 1 to consider all tokens.
#     top_k: Integer that controls the number of top tokens to consider. Set
#         to -1 to consider all tokens.
#     min_p: Float that represents the minimum probability for a token to be
#         considered, relative to the probability of the most likely token.
#         Must be in [0, 1]. Set to 0 to disable this.
#     seed: Random seed to use for the generation.
#     use_beam_search: Whether to use beam search instead of sampling.
#     length_penalty: Float that penalizes sequences based on their length.
#         Used in beam search.
#     early_stopping: Controls the stopping condition for beam search. It
#         accepts the following values: `True`, where the generation stops as
#         soon as there are `best_of` complete candidates; `False`, where an
#         heuristic is applied and the generation stops when is it very
#         unlikely to find better candidates; `"never"`, where the beam search
#         procedure only stops when there cannot be better candidates
#         (canonical beam search algorithm).
#     stop: List of strings that stop the generation when they are generated.
#         The returned output will not contain the stop strings.
#     stop_token_ids: List of tokens that stop the generation when they are
#         generated. The returned output will contain the stop tokens unless
#         the stop tokens are special tokens.
#     include_stop_str_in_output: Whether to include the stop strings in
#         output text. Defaults to False.
#     ignore_eos: Whether to ignore the EOS token and continue generating
#         tokens after the EOS token is generated.
#     max_tokens: Maximum number of tokens to generate per output sequence.
#     min_tokens: Minimum number of tokens to generate per output sequence
#         before EOS or stop_token_ids can be generated
#     logprobs: Number of log probabilities to return per output token.
#         When set to None, no probability is returned. If set to a non-None
#         value, the result includes the log probabilities of the specified
#         number of most likely tokens, as well as the chosen tokens.
#         Note that the implementation follows the OpenAI API: The API will
#         always return the log probability of the sampled token, so there
#         may be up to `logprobs+1` elements in the response.
#     prompt_logprobs: Number of log probabilities to return per prompt token.
#     detokenize: Whether to detokenize the output. Defaults to True.
#     skip_special_tokens: Whether to skip special tokens in the output.
#     spaces_between_special_tokens: Whether to add spaces between special
#         tokens in the output.  Defaults to True.
#     logits_processors: List of functions that modify logits based on
#         previously generated tokens, and optionally prompt tokens as
#         a first argument.
#     truncate_prompt_tokens: If set to an integer k, will use only the last k
#         tokens from the prompt (i.e., left truncation). Defaults to None
#         (i.e., no truncation).
# File:           ~/.local/lib/python3.9/site-packages/vllm/sampling_params.py
# Type:           StructMeta
# Subclasses:

# %%
def generate_with_model(instruction, context_input, model):
    # Generate the prompt using the instruction and context
    prompt = generate_prompt(instruction, context_input)

    # Setup sampling parameters for generation
    # Here we only calculate length to control the output length dynamically
    context_length = len(tokenizer(prompt, return_tensors="pt").input_ids[0])
    print(context_length)
    stop_str = "--- end of response"
    max_input_length = min(2048, tokenizer.model_max_length - context_length)
    sampling_params = SamplingParams(temperature=0.01, max_tokens=max_input_length, stop=stop_str,)

    # Generate the response using the model
    outputs = model.generate(prompt, sampling_params)
    response_text = outputs[0].outputs[0].text  # Adjust based on actual output structure

    # outputs = llm.generate(final_prompt, sampling_params)
    # answer_texts = [output.outputs[0].text for output in outputs]
    
    # # Extract the "Response" part from the generated text
    # response = response_text.split("### Response:")[1].strip()
    # response = response_text.split("--- end of response")[1].strip() 
    
    # Print and return the response
    print(response_text)
    return response_text

# %%
# extract HPI summary USE THIS
def generate_bhc(hadm_id):
    # topic = '''
    # The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
    # from a patient's hospital admission. 
    # You will be provided with input text and data from a specific patient's medical records and clinical notes
    # delimited by xml tags <text> </text>. Use only this data to answer questions about the EHR.  
    # Answer clearly and concisely.
    # '''.replace('\n', '')
    topic = '''
    The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
    from a patient's hospital admission. 
    You will be provided with input text and data from a specific patient's medical records and clinical notes 
    delimited by xml tags <text> </text>. Use only this data to answer questions about the EHR.  
    '''.replace('\n', '').replace('    ', '')
    
    prompt = '''\n
    Write the text for the "brief hospital course" section of a discharge summary note 
    based on the input text using the following template:
    
    Brief Hospital Course
    The patient with a history of [briefly describe the relevent medical history or existing medical problems] 
    presents with [briefly summarize the patient's symptoms]. They were admitted to the [what unit, service or floor were they admitted to?]
    for [briefly summarize the reason for admission, initial diagnosis, and any major procedures or treatments].
    [Briefly summarize the discharge diagnosis at discharge]
    
    Problem-based hospital course---
    # [Medical condition 1] --- [briefly describe presentation and severity for this medical condition or symptom].
    [Summarize the related diagnostic work up and notable results]. 
    [Summarize the related medical or surgical treatment course].

    # [Medical condition 2] -- [briefly describe presentation and severity for this medical condition or symptom].
    [Summarize the diagnostic work up and notable results related to this medical condition]. 
    [Summarize the related medical or surgical treatment course]. 

    --- end of response

    Based on the input text, answer these questions about the patient's hospital admission:
    What are the patient's major medical conditions?
    Why was the patient admitted to the hospital?
    What symptoms did the patient present with? What was the severity and duration of the presenting symptoms?
    What treatments and procedures were administered and for what symptoms or medical conditions?
    What unit or floor were they admitted to?
    What was the diagnostic work up? What were the notable results?
    What medications were used to treat the patient? Were any medications new or discontinued?
    Are there changes to the existing medications?
    What was the patient diagnosed with at discharge?
    What was the patient initially diagnosed with?
    
    Fill in the blanks:
    Use the answers to the questions above to fill in the blanks.
    If you do not know the answer, fill in the blank with "___".
    Answer clearly and concisely. Do not include information about the review of systems.
    Stop generating when you reach "--- end of response"
    Do not repeat the instructions in your response or make comments after your response.
    '''.replace('    ', '')
    
    # Using the following input data as context, 
    # Summarize the patient's hospital course in the following way --
    # Start with brief description of the patient's major medical conditions and why they were admitted to the hospital.
    # Then, in a new section, outline the details of the treatment course and events of the hospital stay, 
    # focusing on the relevant diagnosis, medical conditions,
    # diagnostic work up, relevant results, procedures, medications that were used, and changes to baseline medication therapies. 
    # Organize the outline according to the major medical conditions and diagnosis.
    # Limit your response to 1024 words or less.
    # '''.replace('\n', '')
    # prompt = '''
    # Using the following patient specific data, 
    # briefly summarize the major medical conditions, reason for hospital admission, diagnostic workup, and treatment course.
    # '''.replace('\n', '')
    
    context_str =''
    df = discharge_sections_df
    cur_df = df[df['hadm_id'] == hadm_id]
    cols = ['CC']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = f"The chief complaint was --- {context_data} \n"
    cols = ['HPI']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = context_str + f"The History of present illness --- \n{context_data} \n"
    # cols = ['Medication Lists']
    # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    # context_str = context_str + f"The admission and discharge medication lists:\n{context_data} \n"
    # cols = ['Pertinent Results']
    # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    # context_str = context_str + f"The Pertinent Results were:\n{context_data} \n"
    cols = ['Major Surgical Procedure']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = context_str + f"The major procedures were --- \n{context_data} \n"
    cols = ['Discharge Diagnosis']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = context_str + f"At discharge, the patient was diagnosed with --- \n{context_data} \n"
    context_str = context_str.replace(":", '---').replace("==", '')
    
    df = diagnosis_df
    cols = ['icd_title']
    cur_df = df[df['hadm_id'] == hadm_id]
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n ')
    context_str = context_str + f"The patient was initially diagnosed with ICD Diagnosis titles --- \n{context_data}\n "
    
    
    instruction = f"{topic} \n {prompt}"
    context_input = f"<text> {context_str}</text> "
    
    response = generate_with_model(instruction, context_input, model)
    return response
    
# # extract HPI summary USE THIS
# def generate_bhc(hadm_id):
#     topic = '''
#     The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
#     from a patient's hospital admission. 
#     You will be provided with text and data from a specific patient's medical records and clinical notes
#     delimited by xml tags <text> </text>. Use only this data to answer questions about the EHR.  
#     Answer clearly and concisely.
#     '''.replace('\n', '')
    
#     # prompt = '''
#     # Using the following patient specific data, 
#     # briefly summarize the major medical conditions, reason for hospital admission, diagnostic workup, and treatment course.
#     # Then, create a list of the patient's acute and chronic medical conditions and the associated treatments course.
#     # '''.replace('\n', '')
#     prompt = '''
#     Using the following patient specific data, 
#     briefly summarize the major medical conditions, reason for hospital admission, diagnostic workup, and treatment course.
#     '''.replace('\n', '')
    
#     context_str =''
#     df = discharge_sections_df
#     cur_df = df[df['hadm_id'] == hadm_id]
#     cols = ['CC']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = f"The chief complaint was - {context_data} \n"
#     cols = ['HPI']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = context_str + f"The History of present illness: \n{context_data} \n"
#     # cols = ['Medication Lists']
#     # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     # context_str = context_str + f"The admission and discharge medication lists:\n{context_data} \n"
#     # cols = ['Pertinent Results']
#     # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     # context_str = context_str + f"The Pertinent Results were:\n{context_data} \n"
#     cols = ['Major Surgical Procedure']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = context_str + f"The major procedures were:\n{context_data} \n"
#     cols = ['Discharge Diagnosis']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = context_str + f"The patient was diagnosed with:\n{context_data} \n"
    
#     df = diagnosis_df
#     cols = ['icd_title']
#     cur_df = df[df['hadm_id'] == hadm_id]
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n ')
#     context_str = context_str + f"The patient was initially diagnosed with ICD Diagnosis titles: \n{context_data}\n "
    
    
#     instruction = f"{topic} \n Instruction: {prompt}"
#     context_input = f"<text> Text:{context_str}</text> "
    
#     response = generate_with_model(instruction, context_input, model)
#     return response

# %%
def generate_discharge_instructions(hadm_id):
    # topic = '''
    # The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
    # from a patient's hospital admission. 
    # You will be provided with input text and data from a specific patient's medical records and clinical notes
    # delimited by xml tags <text> </text>. Use only this data to answer questions about the EHR.  
    # Answer clearly and concisely.
    # '''.replace('\n', '')
    
    # prompt = '''
    # Given the following input data from a patient's hospital stay,
    # Compose a letter to the patient that includes answers to the following questions.
    # What was the patient admitted for? What were the major treatments and exam findings?
    # What is the recommended follow-up plan or instructions?
    # Are there any changes to the patient's existing medication, 
    # and if so, what are the new medications, dose changes, or medications that should be stopped?
    # The letter should be courteous, easy to understand, and it should be written in layman's language. 
    # Limit the use of medical jargon and acronyms.
    # Limit your response to 500 words or less.
    # '''.replace('\n', '')

    topic = '''
    The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
    from a patient's hospital admission. 
    You will be provided with input text and data from a specific patient's medical records and clinical notes 
    delimited by xml tags <text> </text>.  
    '''.replace('\n', '').replace('    ', '')
    
    prompt = '''\n
    Write a brief and curteous letter to the patient that summarizes their hospital stay and communicates 
    follow-up instructions as well as important changes to their medications. Use the 
    following template:
    
    Discharge Instructions ---
    Dear ____,

    It was a pleasure to take care of you during your recent hospital admission. 
    You were admitted to the hospital because [explain the reason for admission]. 
    [Briefly explain the diagnostic work up and explain the results]
    During your hospital stay your treatments included [briefly explain the major treatments and procedures].

    [Briefly explain ongoing issues and follow-up recommendations].

    [Briefly explain any new medications and changes to medications].

    If your symptoms return, please call our office (555-555-5555) or 911 for immedicate assistance

    Sincerely,
    Your Team___
    
    --- end of response

    Questions to answer based on the input text:
    Why was the patient admitted to the hospital?
    What treatments and procedures were administered and for what symptoms or medical conditions?
    What was the diagnostic work up related to the chief complaint? What were the notable results?
    What medications were used to treat the patient? Were any medications new or discontinued?
    Are there changes to the existing medications?
    What are the ongoing issues and follow-up recommendations?
    
    Fill in the blanks:
    Use the input data and answers to the questions above to fill in the blanks.
    If you do not know the answer, fill in the blank with "___".
    Answer clearly and concisely. Use easy to understand language or layman's terms.
    Address the patient as "you". Do not refer to the patient in the third person.
    Minimize the use of medical jargon and acronyms.
    Stop generating when you reach "--- end of response".
    Do not repeat the instructions in your response.
    '''.replace('    ', '')
    
    context_str = ''
    df = discharge_sections_df
    cur_df = df[df['hadm_id'] == hadm_id]
    cols = ['CC']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = f"The chief complaint was --- {context_data} \n"
    cols = ['HPI']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = f"The history of present illness was --- {context_data} \n"
    # cols = ['Medication Lists']
    # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    # context_str = context_str + f"The admission and discharge medication list --- \n{context_data} \n"
    cols = ['Transitional Issues']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = context_str + f"The ongoing issues and followup instructions include ---  \n{context_data} \n"
    # cols = ['BHC']
    # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    # context_str = context_str + f"The Brief Hospital course was:\n{context_data} \n"
    cols = ['Discharge Diagnosis']
    context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
    context_str = context_str + f"At discharge, the patient was diagnosed with --- \n{context_data} \n"
    context_str = context_str.replace(":", '---').replace("==", '')
    
    # df = diagnosis_df
    # cols = ['icd_title']
    # cur_df = df[df['hadm_id'] == hadm_id]
    # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n ')
    # context_str = context_str + f"The patient was initially diagnosed with ICD Diagnosis titles --- \n{context_data}\n "
    
    instruction = f"{topic} \n {prompt}"
    context_input = f"<text> {context_str}</text> "
    
    response = generate_with_model(instruction, context_input, model)
    return response
    
# def generate_discharge_instructions(hadm_id):
#     topic = '''
#     The topic is about clinical notes, medical records, and other text documents from electronic health records (EHR) 
#     from a patient's hospital admission. 
#     You will be provided with text and data from a specific patient's medical records and clinical notes
#     delimited by xml tags <text> </text>. Use only this data to answer questions about the EHR.  
#     Answer clearly and concisely.
#     '''.replace('\n', '')
    
#     prompt = '''
#     Given the following information from a patient's hospital stay,
#     Compose a letter to the patient that is courteous and easy to understand. 
#     There should be limited medical jargon and it should be written in layman's language.  
#     The letter will briefly summarize the reason for admission, the treatment course, relevant tests and results.  
#     It will also summarize any changes to the patient's current medical management including medication changes. 
#     Is there any scheduled or recommended follow up?
#     If there was a surgery, what are the post-operative or wound care instructions?
#     Limit the letter to 3 paragraphs.
#     '''.replace('\n', '')
    
#     context_str = ''
#     df = discharge_sections_df
#     cur_df = df[df['hadm_id'] == hadm_id]
#     cols = ['HPI']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = f"The history of present illness was: {context_data} \n"
#     # cols = ['Medication Lists']
#     # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     # context_str = context_str + f"The admission medication list: \n{context_data} \n"
#     cols = ['Transitional Issues']
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     context_str = context_str + f"The ongoing issues to be addressed after discharge: \n{context_data} \n"
#     # cols = ['BHC']
#     # context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n')
#     # context_str = context_str + f"The Brief Hospital course was:\n{context_data} \n"
#     df = diagnosis_df
#     cols = ['icd_title']
#     cur_df = df[df['hadm_id'] == hadm_id]
#     context_data = cur_df[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1).str.cat(sep='\n ')
#     context_str = context_str + f"The patient was initially diagnosed with ICD Diagnosis titles: \n{context_data}\n "
    
    
#     instruction = f"{topic} \n Instruction: {prompt}"
#     context_input = f"<text> Text:{context_str}</text> "
    
#     response = generate_with_model(instruction, context_input, model)
#     discharge_instructions = response
#     return discharge_instructions

# %%
import pandas as pd
import time

# Create an empty results table
results = pd.DataFrame(columns=['hadm_id', 'brief_hospital_course'])

# results path:
results_path = '../data/troyTest/'
file_name = 'results_bhc.csv'
results_file_path = os.path.join(results_path, file_name)

count = 0
total_records = len(target_df.hadm_id)
for hadm_id in target_df['hadm_id'][5:13]:  # Replace with your actual hadm_id values
    count += 1
    percent_complete = count*100/total_records
    print(f"{count} of {total_records}, {percent_complete}% hadm_id: {hadm_id} **********\n\n")
    start_time_bhc = time.time()
    brief_hospital_course = generate_bhc(hadm_id)
    end_time_bhc = time.time()
    duration_bhc = end_time_bhc - start_time_bhc
    print(f"Time taken for generate_bhc: {duration_bhc} seconds.")
    # discharge_instructions = generate_discharge_instructions(hadm_id)
    new_row = pd.DataFrame({'hadm_id': [hadm_id], 'brief_hospital_course': [brief_hospital_course]})
    results = pd.concat([results, new_row], ignore_index=True)
    # results = results.append({'hadm_id': hadm_id, 'brief_hospital_course': brief_hospital_course, 'discharge_instructions': discharge_instructions}, ignore_index=True)
    results.to_csv(results_file_path, index=False)
# Out:
# 1 of 10962, 0.009122422915526365% hadm_id: 28723315 **********
#
#
# 1137
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.70s/it, est. speed input: 307.28 toks/s, output: 79.73 toks/s]
# Brief Hospital Course
# The patient with a history of coronary artery disease, aortic stenosis, and aortic regurgitation presents with left shoulder pain and ST changes on EKG during a routine stress echo. He was admitted to the cardiology service for further management.
#
# Problem-based hospital course---
# # Coronary Artery Disease --- The patient presented with left shoulder pain and ST changes on EKG during a routine stress echo.
# [Summarize the related diagnostic work up and notable results]. The patient had a CTA chest which was negative for aortic dissection.
# [Summarize the related medical or surgical treatment course]. The patient was admitted to the cardiology service for further management.
#
# # Aortic Regurgitation --- The patient presented with severe aortic regurgitation on echocardiography.
# [Summarize the related diagnostic work up and notable results]. The patient had an echocardiography which revealed 4+ aortic regurgitation.
# [Summarize the related medical or surgical treatment course]. The patient was admitted to the cardiology service for further management.
#
# # Aortic Stenosis --- The patient presented with aortic stenosis.
# [Summarize the related diagnostic work up and notable results]. The patient had an echocardiography which revealed aortic stenosis.
# [Summarize the related medical or surgical treatment course]. The patient was admitted to the cardiology service for further management.
#
#
# Time taken for generate_bhc: 3.719733715057373 seconds.
# 2 of 10962, 0.01824484583105273% hadm_id: 22218665 **********
#
#
# 1240
# Processed prompts: 100%|██████████| 1/1 [00:07<00:00,  7.16s/it, est. speed input: 173.28 toks/s, output: 80.49 toks/s]
# Brief Hospital Course
# The patient with a history of HIV infection, hypertension, and schizoaffective disorder presents with intentional overdose of benztropine. He was admitted to the Medical Intensive Care Unit (MICU) for management of benztropine overdose, hypotension, acute kidney injury, rhabdomyolysis, and alcohol withdrawal.
#
# Problem-based hospital course---
# # Benztropine Overdose --- The patient presented with intentional overdose of benztropine, with reported ingestion of 40-150 tablets. He was initially treated with IV fluids and benzodiazepines for sedation.
# [Summarize the related diagnostic work up and notable results]. The patient's initial EKG showed SR@103, IV delay, QTc451, QRS changes. His initial CK was 7666, Cr 3.2, lactate 3.6, after receiving IVF his CK was 6821, Cr 2.5, lactate 2.6.
# [Summarize the related medical or surgical treatment course]. The patient received IV fluids, benzodiazepines for sedation, and a Foley catheter for urine output.
#
# # Hypotension --- The patient presented with hypotension, which was initially treated with IV fluids.
# [Summarize the related diagnostic work up and notable results]. The patient's blood pressure was initially 74/45, and later improved to 90-100s after receiving IV fluids.
# [Summarize the related medical or surgical treatment course]. The patient received IV fluids for hypotension.
#
# # Acute Kidney Injury --- The patient presented with acute kidney injury, which was initially treated with IV fluids.
# [Summarize the related diagnostic work up and notable results]. The patient's initial Cr was 3.2, and later improved to 2.5 after receiving IV fluids.
# [Summarize the related medical or surgical treatment course]. The patient received IV fluids for acute kidney injury.
#
# # Rhabdomyolysis --- The patient presented with rhabdomyolysis, which was initially treated with IV fluids.
# [Summarize the related diagnostic work up and notable results]. The patient's initial CK was 7666, and later improved to 6821 after receiving IV fluids.
# [Summarize the related medical or surgical treatment course]. The patient received IV fluids for rhabdomyolysis.
#
# # Alcohol Withdrawal --- The patient presented with alcohol withdrawal, which was initially treated with benzodiazepines.
# [Summarize the related diagnostic work up and notable results]. The patient's CIWA scale was started, and he received diazepam for sedation.
# [Summarize the related medical or surgical treatment course]. The patient received benzodiazepines for alcohol withdrawal.
#
#
# Time taken for generate_bhc: 7.173907279968262 seconds.
# 3 of 10962, 0.02736726874657909% hadm_id: 25482427 **********
#
#
# 821
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.65s/it, est. speed input: 499.09 toks/s, output: 79.03 toks/s]
# Brief Hospital Course
# The patient with a history of hypertension and remote head injury presents with a fall. They were admitted to the hospital for further workup and evaluation following a presumed syncopal episode.
#
# Problem-based hospital course---
# # Subdural Hematoma --- The patient presented with a presumed syncopal episode and was found to have bifrontal subacute on chronic SDHs with a small, acute right lateral-posterior component.
# The related diagnostic work up included labs which were normal and a CT head and c-spine, which demonstrated chronic degenerative changes but no acute traumatic injury.
# The related medical treatment course included none.
#
#
# Time taken for generate_bhc: 1.660797357559204 seconds.
# 4 of 10962, 0.03648969166210546% hadm_id: 21322534 **********
#
#
# 1263
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.65s/it, est. speed input: 476.94 toks/s, output: 78.92 toks/s]
# Brief Hospital Course
# The patient with a history of CAD, severe aortic stenosis, COPD on 2 L NC, ESRD on HD MWF, hypothyroidism, and chronic pain presents with new onset atrial fibrillation. She was admitted to the cardiology unit for new onset atrial fibrillation, initial diagnosis of demand ischemia, and treatment of hypokalemia.
#
# Problem-based hospital course---
# # Atrial Fibrillation --- The patient presented with new onset atrial fibrillation, which was diagnosed on admission. The diagnostic work up included an EKG, which showed atrial fibrillation with left bundle branch block. The patient was treated with calcium gluconate and insulin for hypokalemia.
#
# # Severe Aortic Stenosis --- The patient has a history of severe aortic stenosis, which was diagnosed on a recent ECHO. The patient was initially diagnosed with demand ischemia, but the diagnosis was later changed to new onset atrial fibrillation.
#
#
# Time taken for generate_bhc: 2.6645469665527344 seconds.
# 5 of 10962, 0.04561211457763182% hadm_id: 22196214 **********
#
#
# 828
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.56s/it, est. speed input: 530.81 toks/s, output: 78.85 toks/s]
# Brief Hospital Course
# The patient with a history of multiple injuries and surgeries presents with severe, pleuritic right scapula pain limiting her mobility. She was admitted to the trauma surgery service for evaluation and management of her symptoms.
# The patient was admitted for evaluation and management of her symptoms, initial diagnosis of right nonhemorrhagic pleural effusion, and right chest tube placement.
#
# Problem-based hospital course---
# # Right scapula pain --- severe, pleuritic pain limiting mobility.
# [Summarize the related diagnostic work up and notable results].
# Right chest tube placement was performed.
#
#
# Time taken for generate_bhc: 1.5738446712493896 seconds.
# 6 of 10962, 0.05473453749315818% hadm_id: 28481035 **********
#
#
# 856
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.43s/it, est. speed input: 249.40 toks/s, output: 80.41 toks/s]
# Brief Hospital Course
# The patient with a history of no significant past medical history
# presents with facial trauma. He was admitted to the surgical
# intensive care unit for management of left mandibular fracture
# and left 10-11 posterior rib fractures. The patient was
# initially diagnosed with fracture of angle of left mandible,
# contusion of lung, unilateral, initial encounter, and assault
# by other bodily force, initial encounter. At discharge, the
# patient was diagnosed with left mandibular fracture and left
# 10-11 posterior rib fractures.
#
# Problem-based hospital course---
# # Left Mandibular Fracture ---
# The patient presented with left mandible tenderness.
# The related diagnostic work up included laboratory testing
# which was significant for white cell count of 17.8. The
# related medical treatment course included open reduction
# internal fixation left mandibular fracture, left angle
# placement of IMF screws and wiring of jaw, and extraction
# of left upper third tooth (Number 16).
#
# # Left 10-11 Posterior Rib Fractures ---
# The patient presented with left chest pain.
# The related diagnostic work up included CT scan of the
# torso which showed a left 10-11 posterior rib fracture.
# The related medical treatment course included management
# of left 10-11 posterior rib fractures.
#
#
# Time taken for generate_bhc: 3.4462990760803223 seconds.
# 7 of 10962, 0.06385696040868455% hadm_id: 25142813 **********
#
#
# 926
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it, est. speed input: 429.49 toks/s, output: 79.31 toks/s]
# Brief Hospital Course
# The patient with a history of rheumatic heart disease, mechanical mitral valve replacement, and history of methicillin-sensitive Staphylococcus aureus (MSSA) endocarditis presents with left sided facial swelling and pain. She was admitted to the medical-surgical floor for left facial/pre-septal cellulitis with likely dental source, supratherapeutic international normalized ratio (INR), and hypertension.
#
# Problem-based hospital course---
# # Left facial/pre-septal cellulitis --- The patient presented with 2 days of left sided facial swelling, redness, and pain. She was given Unasyn for buccal cellulitis.
# [Summarize the related diagnostic work up and notable results]. The patient had a computed tomography (CT) sinus which showed soft tissue edema without abscess.
#
#
# Time taken for generate_bhc: 2.1695289611816406 seconds.
# 8 of 10962, 0.07297938332421092% hadm_id: 29339128 **********
#
#
# 1248
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.43s/it, est. speed input: 364.02 toks/s, output: 79.63 toks/s]
# Brief Hospital Course
# The patient with a history of multiple AVM, seizure disorder, and hypertension presents with confusion, shortness of breath. She was admitted to the Medical Intensive Care Unit (MICU) for acute exacerbation of COPD, acute diastolic heart failure, and hypoxia.
#
# Problem-based hospital course---
# # Confusion and Shortness of Breath --- The patient presented with confusion and shortness of breath, which improved with oxygen therapy.
# [Summarize the related diagnostic work up and notable results]. The patient's mental status reportedly improved while in the ED after receiving oxygen therapy. Repeat ABG showed ___.
# [Summarize the related medical or surgical treatment course]. The patient was put on BiPAP and intermittently desatted to low ___ and had apneic episodes as long as ten seconds.
#
# # Hypoxia --- The patient presented with hypoxia, which was treated with oxygen therapy, lasix, and BiPAP.
# [Summarize the related diagnostic work up and notable results]. The patient's oxygenation improved with nasal cannula and facemask, and then further improved with BiPAP.
# [Summarize the related medical or surgical treatment course]. The patient received 20mg IV lasix in the ED and was put on BiPAP in the MICU.
#
#
# Time taken for generate_bhc: 3.4434804916381836 seconds.

# %%
import time

# Patient ID to be processed
patient_id = 24962904

# Timing generate_bhc function
start_time_bhc = time.time()
brief_hospital_course = generate_bhc(patient_id)
end_time_bhc = time.time()
duration_bhc = end_time_bhc - start_time_bhc
print(f"Time taken for generate_bhc: {duration_bhc} seconds.")

# Timing generate_discharge_instructions function
start_time_di = time.time()
discharge_instructions = generate_discharge_instructions(patient_id)
end_time_di = time.time()
duration_di = end_time_di - start_time_di
print(f"Time taken for generate_discharge_instructions: {duration_di} seconds.")
# Out:
# 1330
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.32s/it, est. speed input: 572.54 toks/s, output: 77.92 toks/s]
# Brief Hospital Course
# The patient with a history of COPD, atrial fibrillation, hypertension, CAD, and hyperlipidemia presents with shortness of breath, cough, and wheezing. She was admitted to the medical floor for COPD exacerbation, initially diagnosed as secondary to steroid taper for recent COPD exacerbation with a component of anxiety.
#
# Problem-based hospital course---
# # COPD Exacerbation --- The patient presented with shortness of breath, increased cough productive of red-reflective sputum, and wheezing since yesterday evening. She was treated with Duonebs and solumedrol 125mg IV.
#
# # Atrial Fibrillation --- The patient has a history of atrial fibrillation on apixaban.
#
# # Hypertension --- The patient has a history of hypertension.
#
# # CAD --- The patient has a history of CAD.
#
#
# Time taken for generate_bhc: 2.3429453372955322 seconds.
# 1348
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.01s/it, est. speed input: 335.87 toks/s, output: 79.48 toks/s]
# Dear Ms. ___,
#
# It was a pleasure to take care of you during your recent hospital admission. You were admitted to the hospital because of shortness of breath, cough, and wheezing. During your hospital stay, your treatments included albuterol inhaler, ipratropium nebs, and prednisone.
#
# Your diagnostic workup included a CT scan that showed emphysema but no evidence of infection. Pulmonary was consulted and recommended increasing your Advair dose to 500/50 and switching from theophylline to roflumilast. However, azithromycin therapy was deferred for outpatient follow-up.
#
# You were initiated on a steroid taper on ___ of prednisone 30 mg for 3 days, then 20 mg for 3 days, then 10 mg until outpatient follow-up.
#
# Your ongoing issues and follow-up recommendations include finishing a 5-day course of Azithromycin, 250mg qd until ___ and an extended prednisone taper for 5 days at 40mg, followed by 10mg taper every 5 days. We would also consider PCP prophylaxis with ___ if unable to wean prednisone to less than 20mg daily. Additionally, your SOB may have an anxiety component, and you may benefit from starting SSRI in addition to your home benzos already prescribed.
#
# If your symptoms return, please call our office (555-555-5555) or 911 for immediate assistance.
#
# Sincerely,
# Your Team___
#
# Time taken for generate_discharge_instructions: 4.027799844741821 seconds.
